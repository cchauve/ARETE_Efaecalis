# %% [markdown]
# # HyAsP results on Enterococcus faecalis data
# ### Cedric Chauve, August 17 2020
#
# This notebook describes the results of HyAsp, with a novel plasmids database generated from the 203 release of RefSeq, on a set of *E. faecalis* samples.

# %%
import sys
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
import collections
from collections import defaultdict
import math

# %%
# Plotting functions

# Bubble plot of two columns of a dataframe
def bubble_plot(df,col1,col2,title,size=1,fs=(10,5),line=False):
    plt.figure(figsize=fs)
    n = len(col1)
    for i in range(n):
        plt.subplot(1,n,i+1)
        X = df[col1[i]]
        Y = df[col2[i]]
        XY = [(X[j],Y[j]) for j in X.keys()]
        XY_count=collections.Counter(XY)
        XX,YY,ZZ = [],[],[]
        for (x,y),z in XY_count.items():
            XX.append(x)
            YY.append(y)
            ZZ.append(z)
        if line:
            lineStart = np.array(XX).min() 
            lineEnd   = np.array(XX).max()  
            plt.plot([lineStart, lineEnd], [lineStart, lineEnd], 'k-', color = 'r')
        plt.scatter(np.array(XX),np.array(YY),s=np.array(ZZ)*size,alpha=0.5)
        plt.xlabel(col1[i])
        plt.ylabel(col2[i])
        plt.title(title[i])
    plt.show()
    
def plot_clustered_stacked(dfall, labels=None, title="multiple stacked bar plot",  H="/", rotation=0, **kwargs):
    """Given a list of dataframes, with identical columns and index, create a clustered stacked bar plot. 
labels is a list of the names of the dataframe, used for the legend
title is a string for the title of the plot
H is the hatch used for identification of the different dataframe"""

    n_df = len(dfall)
    n_col = len(dfall[0].columns) 
    n_ind = len(dfall[0].index)
    axe = plt.subplot(111)

    for df in dfall : # for each data frame
        axe = df.plot(kind="bar",
                      linewidth=0,
                      stacked=True,
                      ax=axe,
                      legend=False,
                      grid=False,
                      **kwargs)  # make bar plots

    h,l = axe.get_legend_handles_labels() # get the handles we want to modify
    for i in range(0, n_df * n_col, n_col): # len(h) = n_col * n_df
        for j, pa in enumerate(h[i:i+n_col]):
            for rect in pa.patches: # for each index
                rect.set_x(rect.get_x() + 1 / float(n_df + 1) * i / float(n_col))
                rect.set_hatch(H * int(i / n_col)) #edited part     
                rect.set_width(1 / float(n_df + 1))

    axe.set_xticks((np.arange(0, 2 * n_ind, 2) + 1 / float(n_df + 1)) / 2.)
    axe.set_xticklabels(df.index, rotation = rotation)
    axe.set_title(title)

    # Add invisible data to add another legend
    n=[]        
    for i in range(n_df):
        n.append(axe.bar(0, 0, color="gray", hatch=H * i))

    l1 = axe.legend(h[:n_col], l[:n_col], loc=[1.01, 0.5])
    if labels is not None:
        l2 = plt.legend(n, labels, loc=[1.01, 0.1]) 
    axe.add_artist(l1)
    return(axe)

# %% [markdown]
# # Data and results
#
# ### HyAsP databases.
# I generated two plasmid databses for HyAsP, both based on the latest release (203) of RefSeq:
# - the first one (full database) contains all plasmid genes,
# - the second one (limited database) contains only genes from *Enterococcus faecalis* genomes from RefSeq 203.
#
# The databases were built with minimal filtering, which might need to be revisited, and are described in the notebook
# [here](../RefSeq/RefSeq203.ipynb).
#
# ### Enterococcus samples.
# I analysed the samples provided with assembly graphs in the GFA format. The samples names are listed in the file [here](./GFA.txt). The GFA files are available in the directory *../McMaster/Unicycler_Assemblies_gfa*.
#
# ### HyAsP results.
# The results are in the directory *./results*, with two directories per sample, one for the results with the full database and one for the results for the limited database.
#
# In each directory, the important files are
# - *[SAMPLE_NAME]_assembly_filtered_gcm.csv*: mapping of the database plasmid genes onto the contigs, filtered out to keep only the mapping that cover at least 95% of the gene length with 95% identity; note that the genes come from GenBank and the gene names correspond to the tag *locus_tag* of GenBank entries. It follows the <a href="http://www.metagenomics.wiki/tools/blast/blastn-output-format-6">tabular output format of BLASTn</a>.
# - *contig_chains.csv*: contigs order and orientation of each putative and questionable plasmid.
# - *putative_plasmids.fasta*: sequence of each putative plasmid.
# - *putative_plasmid_contigs.fasta*: same as above but broken into contigs.
# - *questionable_plasmids.fasta*: sequence of each questionable plasmid.
# - *questionable_plasmid_contigs.fasta*: same as above but broken into contigs.

# %%
# Reading the sample names
RESULTS_DIR  = './results'
GFA_FILE     = './GFA.txt'
SAMPLE_NAMES = [s.rstrip() for s in open(GFA_FILE,'r').readlines()]

# %% [markdown]
# A preliminary analysis showed that there is one sample that has a lot of predicted plasmids with a large cumulated length. This is sample ES-C-ST001-07DEC15-0141J_assembly that has 295 predicted plasmids, and we remove it from the analysis from now.

# %%
SAMPLE_NAMES.remove('ES-C-ST001-07DEC15-0141J_assembly')

# %%
# Reading results: functions
def read_plasmid_features(f):
    data = open(f,'r').readlines()
    output={}
    for plasmid in data:
        if plasmid[0]=='>':
            plasmid_data = plasmid.rstrip().replace('>','').split('\t')
            plasmid_name = plasmid_data[0].split()[0]
            plasmid_seed = plasmid_data[0].split()[1].split('=')[1]
            output[plasmid_name] = {'name':plasmid_name,'seed':plasmid_seed}
            for feature in plasmid_data[1:]:
                field = feature.split('=')[0]
                if field in ['length','num_cds']:
                    value = int(feature.split('=')[1])
                elif field in ['mean_read_depth','gene_density','gc_content']:
                    value = float(feature.split('=')[1])
                elif field == 'circular':
                    value = feature.split('=')[1] == '1'
                else:
                    value = feature.split('=')[1]
                output[plasmid_name][field]=value
    return(output)

def read_sample_results(s):
    plasmids = {}
    # Read contig chains
    with open(RESULTS_DIR+'/'+s+'/contig_chains.csv') as csvfile:
        contig_chains_data = csv.reader(csvfile,delimiter=';')
        for plasmid in contig_chains_data:
            plasmids[plasmid[0]]={'chain':plasmid[1]}            
    # Read plasmids
    def read_features_aux(pref):
        plasmids_file = RESULTS_DIR+'/'+s+'/'+pref+'_plasmids.fasta'
        plasmids_data = read_plasmid_features(plasmids_file)
        for plasmid_name in plasmids_data.keys():
            plasmids[plasmid_name]['putative']=pref=='putative'
            for field,value in plasmids_data[plasmid_name].items():
                plasmids[plasmid_name][field]=value
    # Read putative plasmids
    read_features_aux('putative')
    # Read questionable plasmids
    read_features_aux('questionable')
    # return dataframe
    return(pd.DataFrame.from_dict(plasmids,orient='index'))

# %%
# Reading results
RESULTS_CSV_DONE = False
AUX_FILES_DIR    = 'aux_files'

if RESULTS_CSV_DONE == False:
    RESULTS_FULL_DF = {}
    RESULTS_LIM_DF  = {}
    for sample in SAMPLE_NAMES:
        RESULTS_FULL_DF[sample] = read_sample_results(sample)
        RESULTS_FULL_DF[sample].to_csv(AUX_FILES_DIR+'/'+sample+'_summary.csv')
        RESULTS_LIM_DF[sample]  = read_sample_results(sample+'_Efaecalis')
        RESULTS_LIM_DF[sample].to_csv(AUX_FILES_DIR+'/'+sample+'_Efaecalis_summary.csv')
    RESULTS_CSV_DONE = True
else:
    RESULTS_FULL_DF = {}
    RESULTS_LIM_DF  = {}
    for sample in SAMPLE_NAMES:
        RESULTS_FULL_DF[sample] = pd.read_csv(AUX_FILES_DIR+'/'+sample+'_summary.csv') 
        RESULTS_LIM_DF[sample]  = pd.read_csv(AUX_FILES_DIR+'/'+sample+'_Efaecalis_summary.csv')

# %%
# Access functions        
def sample_nb_plasmids(df):
    if df.shape[0]==0:
        return(0)
    else:
        return(df.loc[df['putative']==True].shape[0])
    
def sample_nb_circ_plasmids(df):
    if df.shape[0]==0:
        return(0)
    else:
        return(df.loc[(df['putative']==True) & (df['circular']==True)].shape[0])
        
def extract_putative_plasmids(df):
    return(df.loc[df['putative']==True])

def extract_questionable_plasmids(df):
    return(df.loc[df['putative']==False])

def contigs_multiset(df):
    result = []
    for chain in df['chain'].values:
        contigs = chain.replace('+','').replace('-','').split(',')
        result += contigs
    return(result)

# %%
# Summarizing results
SUMMARY_CSV_DONE = False

# Mapping function on the individual samples fields to generate the summary
SUMMARY_MAP_DICT = {
    'num_plasmids': lambda df: df.shape[0],
    'sum_length':   lambda df: sum([l for l in df['length'].values]),
    'lengths':      lambda df: [l for l in df['length'].values],
    'num_contigs':  lambda df: sum([len(chain.split(',')) for chain in df['chain'].values]),
    'num_cds':      lambda df: sum([cds for cds in df['num_cds'].values]),
    'read_depth':   lambda df: [rd for rd in df['mean_read_depth'].values],
    'gene_density': lambda df: [gd for gd in df['gene_density'].values],
    'gc_content':   lambda df: [gc for gc in df['gc_content'].values]
} 
SUMMARY_FIELDS = [key+'_full' for key in SUMMARY_MAP_DICT.keys()] + [key+'_lim' for key in SUMMARY_MAP_DICT.keys()]

# Init a summary entry with default values
def init_summary_sample(s,summary_dict):
    summary_dict[s]['name'] = s
    for field in ['num_plasmids','sum_length','num_contigs','num_cds']:
        summary_dict[s][field+'_full'],summary_dict[s][field+'_lim'] = 0,0
    for field in ['lengths','read_depth','gene_density','gc_content']:
        summary_dict[s][field+'_full'],summary_dict[s][field+'_lim'] = [],[]

if SUMMARY_CSV_DONE == False:
    SUMMARY_DICT = {sample:{} for sample in SAMPLE_NAMES}
    for sample in SAMPLE_NAMES:
        # Initialisation to default values corresponding to no putative plasmids
        init_summary_sample(sample,SUMMARY_DICT)
        # Reading individual samples results
        if sample_nb_plasmids(RESULTS_FULL_DF[sample])>0:
            for field,fmap in SUMMARY_MAP_DICT.items():
                SUMMARY_DICT[sample][field+'_full'] = fmap(extract_putative_plasmids(RESULTS_FULL_DF[sample]))
        if sample_nb_plasmids(RESULTS_LIM_DF[sample])>0:
            for field,fmap in SUMMARY_MAP_DICT.items():
                SUMMARY_DICT[sample][field+'_lim'] = fmap(extract_putative_plasmids(RESULTS_LIM_DF[sample]))
    # Final output
    SUMMARY_DF = pd.DataFrame.from_dict(SUMMARY_DICT,orient='index')
    SUMMARY_DF.to_csv(AUX_FILES_DIR+'/summary.csv')
    SUMMARY_CSV_DONE = True
else:
    SUMMARY_DF = pd.read_csv(AUX_FILES_DIR+'/summary.csv')

# %% [markdown]
# ## Analysis

# %% [markdown]
# We first look at a comparison, for all samples, of the putative plasmids predicted with both databases, the full one and the limited one.

# %%
bubble_plot(SUMMARY_DF,
            ['num_plasmids_full','num_contigs_full','sum_length_full'],
            ['num_plasmids_lim','num_contigs_lim','sum_length_lim'],
            ['Number of plasmids','Number of contigs in plasmids','Length of plasmids'],
            fs=(20,5),size=20,line=True)

# %%
bubble_plot(SUMMARY_DF,
            ['num_plasmids_full','num_plasmids_lim'],
            ['sum_length_full','sum_length_lim'],
            ['Number of plasmids versus length (full db)','Number of plasmids versus length (limited db)'],
            fs=(20,5),size=20)

# %% [markdown]
# We can see that for some samples, working with the limited databases results in a larger number of predicted plasmids and/or a larger cumulative length of the predicted plasmids. We list these samples below.

# %%
print('Samples where there are less plasmids with the full database than with the limited:')
for sample in SAMPLE_NAMES:
    num_plasmids_full = SUMMARY_DF.loc[SUMMARY_DF['name']==sample]['num_plasmids_full'].values[0]
    num_plasmids_lim  = SUMMARY_DF.loc[SUMMARY_DF['name']==sample]['num_plasmids_lim'].values[0]
    if num_plasmids_full<num_plasmids_lim:
        print('\t',sample,'\tdifference: ',num_plasmids_lim-num_plasmids_full)
print('Samples where the full database plasmids are shorter overall than the limited database plasmids:')
for sample in SAMPLE_NAMES:
    lg_full = SUMMARY_DF.loc[SUMMARY_DF['name']==sample]['sum_length_full'].values[0]
    lg_lim  = SUMMARY_DF.loc[SUMMARY_DF['name']==sample]['sum_length_lim'].values[0]
    if lg_full<lg_lim:
        print('\t',sample,'\tdifference: ',lg_lim-lg_full)
# Out:
# Samples where there are less plasmids with the full database than with the limited:
# 	 ES-C-ST001-05OCT15-0134I_assembly 	difference:  1
# 	 ES-M-ST001-13OCT14-0050I_assembly 	difference:  1
# 	 ES-M-ST001-19MAY15-0089E_assembly 	difference:  1
# 	 ES-M-ST001-21JUL14-0029K_assembly 	difference:  1
# 	 NS-0228_assembly 	difference:  1
# 	 NS-1131_assembly 	difference:  1
# Samples where the full database plasmids are shorter overall than the limited database plasmids:
# 	 BP-R19-2_assembly 	difference:  50696
# 	 BP-R50-2_assembly 	difference:  51937
# 	 ES-C-ST001-01FEB16-0145M_assembly 	difference:  61640
# 	 ES-C-ST001-05OCT15-0134I_assembly 	difference:  10573
# 	 ES-C-ST001-05OCT15-0134J_assembly 	difference:  66061
# 	 ES-C-ST001-05OCT15-0134K_assembly 	difference:  24614
# 	 ES-C-ST001-27APR15-0081M_assembly 	difference:  3231
# 	 ES-C-ST002-25AUG14-0040K_assembly 	difference:  16982
# 	 ES-M-ST001-03FEB15-0063I_assembly 	difference:  10991
# 	 ES-M-ST001-03MAR15-0067I_assembly 	difference:  15322
# 	 ES-M-ST001-03NOV15-0137L_assembly 	difference:  5619
# 	 ES-M-ST001-13OCT14-0050B_assembly 	difference:  22090
# 	 ES-M-ST001-13OCT14-0050I_assembly 	difference:  6903
# 	 ES-M-ST001-13OCT14-0050K_assembly 	difference:  6585
# 	 ES-M-ST001-21JUL14-0029A_assembly 	difference:  20563
# 	 ES-M-ST001-21JUL14-0029M_assembly 	difference:  25526
# 	 ES-M-ST001-23NOV14-0060I_assembly 	difference:  8861
# 	 NS-0004_assembly 	difference:  63816
# 	 NS-0026_assembly 	difference:  26043
# 	 NS-0057_assembly 	difference:  25008
# 	 NS-0077_assembly 	difference:  35982
# 	 NS-0209_assembly 	difference:  60096
# 	 NS-0228_assembly 	difference:  44536
# 	 NS-0290_assembly 	difference:  1328
# 	 NS-0305_assembly 	difference:  12803
# 	 NS-0332_assembly 	difference:  127130
# 	 NS-0340_assembly 	difference:  162058
# 	 NS-0355_assembly 	difference:  6116
# 	 NS-0372_assembly 	difference:  16792
# 	 NS-0822_assembly 	difference:  11456
# 	 NS-0992_assembly 	difference:  27406
# 	 NS-1090_assembly 	difference:  20549
# 	 NS-1114_assembly 	difference:  852
# 	 NS-1117_assembly 	difference:  10810
# 	 NS-1131_assembly 	difference:  120867
# 	 NS-1184_assembly 	difference:  89807
# 	 NS-1289_assembly 	difference:  57476
# 	 SS-0002_assembly 	difference:  937
# 	 SS-0004_assembly 	difference:  76092
# 	 SS-0007_assembly 	difference:  8883
# 	 SS-0008_assembly 	difference:  122028
# 	 SS-0022_assembly 	difference:  6017
# 	 SS-0028_assembly 	difference:  25147
# 	 SS-0042_assembly 	difference:  32303
# 	 SWEntR-0244_assembly 	difference:  16381

# %% [markdown]
# We look at the number of circular predicted plasmids.

# %%
for sample in SAMPLE_NAMES:
    nb_circ_full = sample_nb_circ_plasmids(RESULTS_FULL_DF[sample])
    nb_circ_lim  = sample_nb_circ_plasmids(RESULTS_LIM_DF[sample])
    if nb_circ_lim>0 or nb_circ_full>0:
        print('\t',sample,'\tfull db: ',nb_circ_full,' circular plasmids\t-\tlimited db: ',nb_circ_lim,' circular plasmids.')
# Out:
# 	 BP-G109-2_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 BP-G138E-2_assembly 	full db:  2  circular plasmids	-	limited db:  1  circular plasmids.
# 	 BP-G149-3_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 BP-G42-1_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 BP-G69E-3_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 BP-H22-1_assembly 	full db:  0  circular plasmids	-	limited db:  1  circular plasmids.
# 	 BP-H4-1_assembly 	full db:  3  circular plasmids	-	limited db:  2  circular plasmids.
# 	 BP-H44-3_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 BP-H96E-2_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 BP-R20-1_assembly 	full db:  3  circular plasmids	-	limited db:  2  circular plasmids.
# 	 BP-R26E-1_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 BP-R29-2_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 BP-R30-1_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 BP-R37-3_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 BP-R49-3_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 BP-R51-2_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 BP-R52-1_assembly 	full db:  4  circular plasmids	-	limited db:  2  circular plasmids.
# 	 BP-R53-2_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 BP-R5E-3_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 BP-R7-1_assembly 	full db:  2  circular plasmids	-	limited db:  3  circular plasmids.
# 	 BP-W84-1_assembly 	full db:  2  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-A-FC201-20OCT14-0203C_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-A-FC208-23FEB16-0800A_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-A-FC303-10AUG15-0566I_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-A-FC304-08JUN15-0497J_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-A-FC504-20OCT14-0213I_assembly 	full db:  2  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-A-FC604-20OCT14-0216B_assembly 	full db:  3  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-A-FC604-20OCT14-0216K_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-A-FC606-15DEC15-0736C_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-A-FC606-20OCT14-0217B_assembly 	full db:  2  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-A-FC606-20OCT14-0217I_assembly 	full db:  0  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-A-FC606-20OCT14-0217J_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-01FEB16-0145A_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-01FEB16-0145B_assembly 	full db:  0  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-05OCT15-0134I_assembly 	full db:  0  circular plasmids	-	limited db:  2  circular plasmids.
# 	 ES-C-ST001-05OCT15-0134K_assembly 	full db:  0  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-07DEC15-0141B_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-07DEC15-0141C_assembly 	full db:  0  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-07DEC15-0141D_assembly 	full db:  2  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-07DEC15-0141K_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-07DEC15-0141L_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-15DEC14-0062J_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-15DEC14-0062K_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-15DEC14-0062L_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-15DEC14-0062M_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 ES-C-ST001-17FEB15-0065A_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-C-ST001-17FEB15-0065I_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-17FEB15-0065J_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-17FEB15-0065K_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-C-ST001-17FEB15-0065M_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-20OCT14-0053M_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST001-25AUG14-0039C_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 ES-C-ST001-25AUG15-0117K_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 ES-C-ST002-25AUG14-0040D_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-C-ST002-25AUG14-0040K_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-03FEB15-0063I_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-03FEB15-0063J_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-03FEB15-0063L_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-03FEB15-0063M_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-03MAR15-0067C_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-03MAR15-0067I_assembly 	full db:  3  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-03MAY16-0152I_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-03NOV15-0137B_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-03NOV15-0137D_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-M-ST001-03NOV15-0137M_assembly 	full db:  2  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-05JAN16-0143I_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-13OCT14-0050B_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-M-ST001-13OCT14-0050J_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 ES-M-ST001-13OCT14-0050K_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-19MAY15-0089A_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 ES-M-ST001-19MAY15-0089C_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-M-ST001-19MAY15-0089D_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 ES-M-ST001-19MAY15-0089I_assembly 	full db:  1  circular plasmids	-	limited db:  2  circular plasmids.
# 	 ES-M-ST001-19MAY15-0089M_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-21JUL14-0029A_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-M-ST001-21JUL14-0029C_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-M-ST001-21JUL14-0029D_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-21JUL14-0029J_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-M-ST001-21JUL14-0029K_assembly 	full db:  1  circular plasmids	-	limited db:  2  circular plasmids.
# 	 ES-M-ST001-21JUL14-0029L_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-M-ST001-21JUL14-0029M_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 ES-M-ST001-23NOV14-0060J_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 ES-M-ST001-23NOV14-0060K_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-M-ST001-23NOV14-0060L_assembly 	full db:  2  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST001-23NOV14-0060M_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-M-ST002-23NOV14-0061A_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-S-FC022-12MAY14-0021E_assembly 	full db:  2  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-S-FC072-15SEP14-0172A_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 ES-S-FC302-12MAY14-0034E_assembly 	full db:  2  circular plasmids	-	limited db:  1  circular plasmids.
# 	 ES-S-FC400-14MAR16-0827I_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0026_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0053_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0078_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 NS-0095_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0131_assembly 	full db:  0  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0150_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 NS-0200_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 NS-0205_assembly 	full db:  1  circular plasmids	-	limited db:  2  circular plasmids.
# 	 NS-0209_assembly 	full db:  0  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0228_assembly 	full db:  0  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0305_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0331_assembly 	full db:  2  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0332_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 NS-0355_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0372_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0383_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0395_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0405_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0539_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0687_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0747_assembly 	full db:  0  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0822_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 NS-0884_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0889_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-0898_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-1020_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-1066_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-1090_assembly 	full db:  1  circular plasmids	-	limited db:  2  circular plasmids.
# 	 NS-1105_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-1106_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-1124_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 NS-1131_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-1132_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-1171_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-1184_assembly 	full db:  0  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-1214_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-1309_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 NS-1412_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 NS-1492_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 NS-1649_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 NS-1693_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 SS-0002_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 SS-0004_assembly 	full db:  0  circular plasmids	-	limited db:  1  circular plasmids.
# 	 SS-0007_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 SS-0008_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 SS-0011_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 SS-0016_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 SS-0017_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 SS-0029_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 SS-0034_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 SS-0037_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 SS-0038_assembly 	full db:  2  circular plasmids	-	limited db:  1  circular plasmids.
# 	 SS-0039_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 SS-0040_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 SS-0042_assembly 	full db:  1  circular plasmids	-	limited db:  1  circular plasmids.
# 	 SWEnt-1134_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 SWEnt-1223_assembly 	full db:  1  circular plasmids	-	limited db:  0  circular plasmids.
# 	 SWEntR-0252_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 SWEntR-0295_assembly 	full db:  2  circular plasmids	-	limited db:  2  circular plasmids.
# 	 SWEntR-0374_assembly 	full db:  2  circular plasmids	-	limited db:  1  circular plasmids.

# %% [markdown]
# Now we look at the distribution of the length of the putative plasmids for each sample.

# %%
PREFIXES = ['BP', 'En', 'ES', 'ES-C', 'ES-M', 'NS', 'SS', 'SW']

# %%
# Stacked bar chart of the plasmids and their length
# Gathering actual lengths
PLASMIDS_LG_FULL_DICT = {prefix: {} for prefix in PREFIXES}
PLASMIDS_LG_LIM_DICT = {prefix: {} for prefix in PREFIXES}

for sample in SAMPLE_NAMES:
    prefix = sample[0:4]
    if prefix not in PREFIXES:
        prefix = sample[0:2]
    PLASMIDS_LG_FULL_DICT[prefix][sample] = SUMMARY_DF.loc[SUMMARY_DF['name']==sample]['lengths_full'].values[0]
    PLASMIDS_LG_LIM_DICT[prefix][sample] = SUMMARY_DF.loc[SUMMARY_DF['name']==sample]['lengths_lim'].values[0]
# Maximum number of plasmids
MAX_NUM_PLASMIDS_FULL = max(SUMMARY_DF['num_plasmids_full'])
MAX_NUM_PLASMIDS_LIM  = max(SUMMARY_DF['num_plasmids_lim'])
MAX_NUM_PLASMIDS = max([MAX_NUM_PLASMIDS_FULL,MAX_NUM_PLASMIDS_LIM])
# Completing each length list by zeros to have the same number of entries in each list
for sample in SAMPLE_NAMES:
    prefix = sample[0:4]
    if prefix not in PREFIXES:
        prefix = sample[0:2]
    nb_zeros_full = MAX_NUM_PLASMIDS-len(PLASMIDS_LG_FULL_DICT[prefix][sample])
    for i in range(nb_zeros_full):
        PLASMIDS_LG_FULL_DICT[prefix][sample].append(0)
    PLASMIDS_LG_FULL_DICT[prefix][sample].sort(reverse=True)
    nb_zeros_lim = MAX_NUM_PLASMIDS-len(PLASMIDS_LG_LIM_DICT[prefix][sample])
    for i in range(nb_zeros_lim):
        PLASMIDS_LG_LIM_DICT[prefix][sample].append(0)
    PLASMIDS_LG_LIM_DICT[prefix][sample].sort(reverse=True)
# Creating dataframes

PLASMIDS_LG_FULL_DF = {}
PLASMIDS_LG_LIM_DF = {}
for prefix in PREFIXES:
    PLASMIDS_LG_FULL_DF[prefix] = pd.DataFrame.from_dict(PLASMIDS_LG_FULL_DICT[prefix],orient='index')
    PLASMIDS_LG_LIM_DF[prefix] = pd.DataFrame.from_dict(PLASMIDS_LG_LIM_DICT[prefix],orient='index')

# %%
plot_clustered_stacked([PLASMIDS_LG_FULL_DF['BP'],PLASMIDS_LG_LIM_DF['BP']],['full db','limited db'],H='\\\\\\',rotation=90,figsize=(25,6), title='Samples starting by BP')

# %%
plot_clustered_stacked([PLASMIDS_LG_FULL_DF['En'],PLASMIDS_LG_LIM_DF['En']],['full db','limited db'],H='\\\\\\',rotation=90,figsize=(25,6), title='Samples starting by En')

# %%
plot_clustered_stacked([PLASMIDS_LG_FULL_DF['ES'],PLASMIDS_LG_LIM_DF['ES']],['full db','limited db'],H='\\\\\\',rotation=90,figsize=(25,6), title='Samples starting by ES-[A,S,F,V]')

# %%
plot_clustered_stacked([PLASMIDS_LG_FULL_DF['ES-C'],PLASMIDS_LG_LIM_DF['ES-C']],['full db','limited db'],H='\\\\\\',rotation=90,figsize=(25,6), title='Samples starting by ES-C')

# %%
plot_clustered_stacked([PLASMIDS_LG_FULL_DF['ES-M'],PLASMIDS_LG_LIM_DF['ES-M']],['full db','limited db'],H='\\\\\\',rotation=90,figsize=(25,6), title='Samples starting by ES-M')

# %%
plot_clustered_stacked([PLASMIDS_LG_FULL_DF['NS'],PLASMIDS_LG_LIM_DF['NS']],['full db','limited db'],H='\\\\\\',rotation=90,figsize=(25,6), title='Samples starting by NS')

# %%
plot_clustered_stacked([PLASMIDS_LG_FULL_DF['SS'],PLASMIDS_LG_LIM_DF['SS']],['full db','limited db'],H='\\\\\\',rotation=90,figsize=(25,8), title='Samples starting by SS')

# %%
plot_clustered_stacked([PLASMIDS_LG_FULL_DF['SW'],PLASMIDS_LG_LIM_DF['SW']],['full db','limited db'],H='\\\\\\',rotation=90,figsize=(25,6), title='Samples starting by SW')

# %% [markdown]
# Overall there seems to be some agreement between the plasmids obtained with the two databases. To assess this, we look at the difference in terms of contigs content and length of predicted plasmids.

# %%
# Differences between the results obtained with the two databases
def contigs_multiset_difference(sample):
    if sample_nb_plasmids(RESULTS_FULL_DF[sample]) > 0:
        a = collections.Counter(contigs_multiset(RESULTS_FULL_DF[sample].loc[RESULTS_FULL_DF[sample]['putative']==True]))
    else:
        a = collections.Counter([])
    if sample_nb_plasmids(RESULTS_LIM_DF[sample]) > 0:
        b = collections.Counter(contigs_multiset(RESULTS_LIM_DF[sample].loc[RESULTS_LIM_DF[sample]['putative']==True]))
    else:
        b = collections.Counter([])
    difference = a - b
    return(sum(difference.values()))  # Remove this line if you want it as a list

def plasmids_length_difference(sample):
    return(abs(SUMMARY_DF.loc[SUMMARY_DF['name']==sample]['sum_length_full'].values[0]-SUMMARY_DF.loc[SUMMARY_DF['name']==sample]['sum_length_lim'].values[0]))

# %%
DIFFERENCE_PLASMIDS_DICT = {sample:{'num_contigs':0,'length':0} for sample in SAMPLE_NAMES}
for sample in SAMPLE_NAMES:
    DIFFERENCE_PLASMIDS_DICT[sample]['num_contigs'] = contigs_multiset_difference(sample)
    DIFFERENCE_PLASMIDS_DICT[sample]['length']      = plasmids_length_difference(sample)
DIFFERENCE_PLASMIDS_DF = pd.DataFrame.from_dict(DIFFERENCE_PLASMIDS_DICT,orient='index')

# %%
bubble_plot(DIFFERENCE_PLASMIDS_DF,
            ['num_contigs'],
            ['length'],
            ['Difference in terms of contigs content and length between the two db'],
            fs=(10,5),size=20)

# %% [markdown]
# There is a concentration close to the origin, corresponding to cases where the difference between the two databases is not too signiifcant, but there are quite a few cases where the difference is very large, both in terms of contigs content and of length.
